# %%
from keras.datasets import cifar10
# Out:
# Using Theano backend.
# Using gpu device 0: Quadro M6000 (CNMeM is disabled, cuDNN 4007)

# %%
(xtrain, ytrain), (xtest, ytest) = cifar10.load_data()

# %%
import numpy as np
from PIL import Image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(xtrain[0, 1])

# %%
padded =np.pad(xtrain[0].transpose(1,2,0), ((16,16), (16,16), (0,0)), mode='reflect' )
plt.imshow(padded)

# %%
img = Image.fromarray(padded)

# %%
img20 = img.rotate(20)
plt.imshow(np.array(img20))

# %%
plt.imshow(np.array(img20)[16:-16, 16:-16])
